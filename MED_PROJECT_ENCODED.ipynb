# %%
#liberary airdrop
import pandas as pd
import numpy as np
import plotly.express as px
from category_encoders import BinaryEncoder as be
from sklearn.model_selection import train_test_split as tts
from category_encoders import BinaryEncoder as be

# %%
df=pd.read_csv("cleaned_laptops_dataset.csv")
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1236    Asus            Notebook    15.6
# 1237  Lenovo  2 in 1 Convertible    14.0
# 1238  Lenovo  2 in 1 Convertible    13.3
# 1239  Lenovo            Notebook    14.0
# 1240      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1236                                    1366x768
# 1237   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1241 non-null   object
#  1   TypeName          1241 non-null   object
#  2   Inches            1241 non-null   float64
#  3   ScreenResolution  1241 non-null   object
#  4   Cpu               1241 non-null   object
#  5   Ram               1241 non-null   float64
#  6   Memory            1241 non-null   object
#  7   Gpu               1241 non-null   object
#  8   OpSys             1241 non-null   object
#  9   Weight            1241 non-null   float64
#  10  Price             1241 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 106.8+ KB

# %% [markdown]
# ## here i will encode categorical columns according to the following:
# #### 1-company, operation system and laptop type(TypeName) will be encoded by binary encoder since their quality and performance are debatable
# #### 2-the rest of categoricals will be encoded by mapping

# %% [markdown]
# ### company encoding

# %%
encoder=be()

# %%
company_enc=encoder.fit_transform(df[["Company"]])

# %%
df=pd.concat([df,company_enc],axis=1)

# %%
df.drop("Company",axis=1,inplace=True)

# %%
df
# Out:
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1236            Notebook    15.6                                    1366x768
# 1237  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1238  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1239            Notebook    14.0                                    1366x768
# 1240            Notebook    15.6                                    1366x768
#
# ...

# %% [markdown]
# ### type name encoding

# %%
type_enc=encoder.fit_transform(df[["TypeName"]])

# %%
df=pd.concat([df,type_enc],axis=1)

# %%
df.drop("TypeName",axis=1,inplace=True)

# %%
df
# Out:
#       Inches                            ScreenResolution  \
# 0       13.3          IPS Panel Retina Display 2560x1600
# 1       13.3                                    1440x900
# 2       15.6                           Full HD 1920x1080
# 3       15.4          IPS Panel Retina Display 2880x1800
# 4       13.3          IPS Panel Retina Display 2560x1600
# ...      ...                                         ...
# 1236    15.6                                    1366x768
# 1237    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1238    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1239    14.0                                    1366x768
# 1240    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                     Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# ...

# %% [markdown]
# ### OS encoding

# %%
OS_enc=encoder.fit_transform(df[["OpSys"]])

# %%
df=pd.concat([df,OS_enc],axis=1)

# %%
df.drop("OpSys",axis=1,inplace=True)

# %%
df
# Out:
#       Inches                            ScreenResolution  \
# 0       13.3          IPS Panel Retina Display 2560x1600
# 1       13.3                                    1440x900
# 2       15.6                           Full HD 1920x1080
# 3       15.4          IPS Panel Retina Display 2880x1800
# 4       13.3          IPS Panel Retina Display 2560x1600
# ...      ...                                         ...
# 1236    15.6                                    1366x768
# 1237    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1238    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1239    14.0                                    1366x768
# 1240    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                     Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# ...

# %%
df["ScreenResolution"].unique().tolist()
# Out:
# ['IPS Panel Retina Display 2560x1600',
#  '1440x900',
#  'Full HD 1920x1080',
#  'IPS Panel Retina Display 2880x1800',
#  '1366x768',
#  'IPS Panel Full HD 1920x1080',
#  'IPS Panel Retina Display 2304x1440',
#  'IPS Panel Full HD / Touchscreen 1920x1080',
#  'Full HD / Touchscreen 1920x1080',
#  'Touchscreen / Quad HD+ 3200x1800',
#  'Touchscreen 2256x1504',
#  'Quad HD+ / Touchscreen 3200x1800',
#  'IPS Panel 1366x768',
#  'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#  'IPS Panel Full HD 2160x1440',
#  '4K Ultra HD / Touchscreen 3840x2160',
#  '1600x900',
#  'IPS Panel 4K Ultra HD 3840x2160',
#  '4K Ultra HD 3840x2160',
#  'Touchscreen 1366x768',
#  'Touchscreen 2560x1440',
#  'IPS Panel Full HD 1366x768',
#  'IPS Panel 2560x1440',
#  'IPS Panel Full HD 2560x1440',
#  'IPS Panel Retina Display 2736x1824',
#  'Touchscreen 2400x1600',
#  '2560x1440',
#  'IPS Panel Quad HD+ 2560x1440',
#  'IPS Panel Quad HD+ 3200x1800',
#  'IPS Panel Quad HD+ / Touchscreen 3200x1800',
# ...

# %% [markdown]
# ## the role of binary encoder is done and now it is time to use mapping

# %% [markdown]
# #### note: since values are many: i am using chat GPT to map by asking him to sort the values ascending by their performance and quality so there might be problems , i am not using label encoder since it will just sort them by appearnce order

# %% [markdown]
# ### GPU mapping

# %%
GPU_dict={'Intel HD Graphics': 1,
    'Intel HD Graphics 400': 2,
    'Intel HD Graphics 405': 3,
    'Intel HD Graphics 500': 4,
    'Intel HD Graphics 505': 5,
    'Intel HD Graphics 510': 6,
    'Intel HD Graphics 515': 7,
    'Intel HD Graphics 520': 8,
    'Intel HD Graphics 530': 9,
    'Intel HD Graphics 5300': 10,
    'Intel HD Graphics 540': 11,
    'Intel HD Graphics 615': 12,
    'Intel HD Graphics 620': 13,
    'Intel HD Graphics 630': 14,
    'Intel Iris Graphics 540': 15,
    'Intel Iris Graphics 550': 16,
    'Intel Iris Plus Graphics 640': 17,
    'Intel Iris Plus Graphics 650': 18,
    'Intel UHD Graphics 620': 19,
    'AMD FirePro W4190M': 20,
    'AMD FirePro W4190M ': 21,
    'AMD FirePro W5130M': 22,
    'AMD FirePro W6150M': 23,
    'AMD Radeon 520': 24,
    'AMD Radeon 530': 25,
    'AMD Radeon 540': 26,
    'AMD Radeon RX 550': 27,
    'AMD Radeon R2': 28,
    'AMD Radeon R2 Graphics': 29,
    'AMD Radeon R3': 30,
    'AMD Radeon R4': 31,
    'AMD Radeon R4 Graphics': 32,
    'AMD Radeon R5': 33,
    'AMD Radeon R5 430': 34,
    'AMD Radeon R5 520': 35,
    'AMD Radeon R5 M315': 36,
    'AMD Radeon R5 M330': 37,
    'AMD Radeon R5 M420': 38,
    'AMD Radeon R5 M420X': 39,
    'AMD Radeon R5 M430': 40,
    'AMD Radeon R5 M440': 41,
    'AMD Radeon R5 M315': 42,
    'AMD Radeon R7': 43,
    'AMD Radeon R7 Graphics': 44,
    'AMD Radeon R7 M360': 45,
    'AMD Radeon R7 M365X': 46,
    'AMD Radeon R7 M440': 47,
    'AMD Radeon R7 M445': 48,
    'AMD Radeon R9 M385': 49,
    'AMD Radeon RX 540': 50,
    'AMD Radeon RX 560': 51,
    'AMD Radeon RX 580': 52,
    'Nvidia GeForce 920': 53,
    'Nvidia GeForce 920M': 54,
    'Nvidia GeForce 920MX': 55,
    'Nvidia GeForce 920MX ': 56,
    'Nvidia GeForce 930M': 57,
    'Nvidia GeForce 930MX': 58,
    'Nvidia GeForce 930MX ': 59,
    'Nvidia GeForce 940M': 60,
    'Nvidia GeForce 940MX': 61,
    'Nvidia GeForce 940MX ': 62,
    'Nvidia GeForce 950M': 63,
    'Nvidia GeForce 960': 64,
    'Nvidia GeForce 960M': 65,
    'Nvidia GeForce 965M': 66,
    'Nvidia GeForce 970M': 67,
    'Nvidia GeForce 980': 68,
    'Nvidia GeForce 980 ': 69,
    'Nvidia GeForce 980M': 70,
    'Nvidia GeForce 1050M': 71,
    'Nvidia GeForce 1050Ti': 72,
    'Nvidia GeForce 1060': 73,
    'Nvidia GeForce 1070': 74,
    'Nvidia GeForce 1070M': 75,
    'Nvidia GeForce 1080': 76,
    'Nvidia GeForce 150MX': 77,
    'Nvidia GeForce GTX 1050': 78,
    'Nvidia GeForce GTX 1050M': 79,
    'Nvidia GeForce GTX 1050Ti': 80,
    'Nvidia GeForce GTX 1060': 81,
    'Nvidia GeForce GTX 1070': 82,
    'Nvidia GeForce GTX 1070M': 83,
    'Nvidia GeForce GTX 1080': 84,
    'Nvidia GeForce GTX 960': 85,
    'Nvidia GeForce GTX 960M': 86,
    'Nvidia GeForce GTX 970M': 87,
    'Nvidia GeForce GTX 980M': 88,
    'Nvidia GeForce GTX 1050': 89,
    'Nvidia GeForce GTX 1050 Ti': 90,
    'Nvidia GeForce GTX 1060': 91,
    'Nvidia GeForce GTX 1070': 92,
    'Nvidia GeForce GTX 1080': 93,
    'Nvidia GTX 980 SLI': 94,
    'Nvidia Quadro 3000M': 95,
    'Nvidia Quadro M1000M': 96,
    'Nvidia Quadro M1200': 97,
    'Nvidia Quadro M2000M': 98,
    'Nvidia Quadro M2200': 99,
    'Nvidia Quadro M2200M': 100,
    'Nvidia Quadro M3000M': 101,
    'Nvidia Quadro M500M': 102,
    'Nvidia Quadro M520M': 103,
}

# %%
df["Gpu"]=df["Gpu"].map(GPU_dict)

# %%
df.sample(20)
# Out:
#       Inches                           ScreenResolution  \
# 1036    13.3            Full HD / Touchscreen 1920x1080
# 1193    15.6                                   1366x768
# 913     17.3                                   1600x900
# 980     15.6                          Full HD 1920x1080
# 127     14.0                IPS Panel Full HD 1920x1080
# 798     15.6                          Full HD 1920x1080
# 110     14.0                         IPS Panel 1366x768
# 1098    17.3                IPS Panel Full HD 1920x1080
# 528     13.3               IPS Panel Quad HD+ 3200x1800
# 328     15.6                          Full HD 1920x1080
# 282     17.3                                   1600x900
# 990     15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 680     15.6                          Full HD 1920x1080
# 1220    14.0                IPS Panel Full HD 1920x1080
# 81      15.6                                   1366x768
# 673     17.3                          Full HD 1920x1080
# ...

# %% [markdown]
# ### screen resolution mapping

# %%
df["ScreenResolution"].nunique()
# Out:
# 40

# %%
SC_dict={
    '1366x768': 0,
    'IPS Panel 1366x768': 1,
    'IPS Panel Full HD 1366x768': 2,
    'IPS Panel Full HD 1920x1080': 3,
    'Full HD 1920x1080': 4,
    'IPS Panel Full HD 1920x1200': 5,
    'Touchscreen / Full HD 1920x1080': 6,
    'IPS Panel Touchscreen 1920x1200': 7,
    '1440x900': 8,
    '1600x900': 9,
    'IPS Panel 2560x1440': 10,
    'IPS Panel Full HD 2560x1440': 11,
    '2560x1440': 12,
    'IPS Panel Quad HD+ 2560x1440': 13,
    'Touchscreen 2256x1504': 14,
    'IPS Panel 4K Ultra HD 3840x2160': 15,
    '4K Ultra HD 3840x2160': 16,
    'IPS Panel Retina Display 2304x1440': 17,
    'IPS Panel Retina Display 2560x1600': 18,
    'IPS Panel Retina Display 2736x1824': 19,
    'IPS Panel Retina Display 2880x1800': 20,
    'Touchscreen / Quad HD+ 3200x1800': 21,
    'Quad HD+ 3200x1800': 22,
    'IPS Panel Quad HD+ 3200x1800': 23,
    'IPS Panel Quad HD+ / Touchscreen 3200x1800': 24,
    'Quad HD+ / Touchscreen 3200x1800': 25,
    'IPS Panel Touchscreen 2400x1600': 26,
    'Touchscreen 2400x1600': 27,
    'IPS Panel 4K Ultra HD / Touchscreen 3840x2160': 28,
    '4K Ultra HD / Touchscreen 3840x2160': 29,
    'IPS Panel Full HD / Touchscreen 1920x1080': 30,
    'Full HD / Touchscreen 1920x1080': 31,
    'Touchscreen / 4K Ultra HD 3840x2160': 32,
    'IPS Panel Touchscreen / 4K Ultra HD 3840x2160': 33,
    'Touchscreen 1366x768': 34,
    'IPS Panel Touchscreen 1366x768': 35,
    'IPS Panel 1366x768': 36,
    'IPS Panel Full HD 2160x1440': 37,
    'Touchscreen / Full HD+ 2160x1440': 38,
    'IPS Panel Full HD+ 1920x1200': 39
}

# %%
df["ScreenResolution"]=df["ScreenResolution"].map(SR_dict)

# %%
df.sample(20)
# Out:
#       Inches  ScreenResolution                                   Cpu   Ram  \
# 231     15.6               NaN              Intel Core i3 6006U 2GHz   8.0
# 89      13.3               NaN            Intel Core i7 8550U 1.8GHz  16.0
# 790     14.0               NaN            Intel Core i7 7500U 2.7GHz   8.0
# 1189    15.6               NaN           Intel Core i7 6700HQ 2.6GHz   8.0
# 577     31.6              23.0              Intel Core M 7Y30 1.0GHz   4.0
# 394     13.3               NaN            Intel Core i7 6500U 2.5GHz  16.0
# 1095    10.1              18.0           Intel Atom x5-Z8550 1.44GHz   4.0
# 490     11.6               NaN  Intel Celeron Dual Core N3060 1.6GHz   4.0
# 187     13.3               9.0            Intel Core i7 8550U 1.8GHz   8.0
# 1012    15.6               5.0            Intel Core i7 6500U 2.5GHz  16.0
# 235     13.9               9.0            Intel Core i7 7500U 2.7GHz   8.0
# ...

# %% [markdown]
# ### CPU mapping

# %%
df["Cpu"].nunique()
# Out:
# 118

# %%
CPU_dict={
    'Intel Core i5 2.3GHz': 1,
    'Intel Core i5 1.8GHz': 2,
    'Intel Core i5 7200U 2.5GHz': 3,
    'Intel Core i7 2.7GHz': 4,
    'Intel Core i5 3.1GHz': 5,
    'AMD A9-Series 9420 3GHz': 6,
    'Intel Core i7 2.2GHz': 7,
    'Intel Core i7 8550U 1.8GHz': 8,
    'Intel Core i5 8250U 1.6GHz': 9,
    'Intel Core i3 6006U 2GHz': 10,
    'Intel Core i7 2.8GHz': 11,
    'Intel Core M m3 1.2GHz': 12,
    'Intel Core i7 7500U 2.7GHz': 13,
    'Intel Core i7 2.9GHz': 14,
    'Intel Core i3 7100U 2.4GHz': 15,
    'Intel Core i5 7300HQ 2.5GHz': 16,
    'AMD E-Series E2-9000e 1.5GHz': 17,
    'Intel Core i5 1.6GHz': 18,
    'Intel Core i7 8650U 1.9GHz': 19,
    'Intel Atom x5-Z8300 1.44GHz': 20,
    'AMD E-Series E2-6110 1.5GHz': 21,
    'AMD A6-Series 9220 2.5GHz': 22,
    'Intel Celeron Dual Core N3350 1.1GHz': 23,
    'Intel Core i3 7130U 2.7GHz': 24,
    'Intel Core i7 7700HQ 2.8GHz': 25,
    'Intel Core i5 2.0GHz': 26,
    'AMD Ryzen 1700 3GHz': 27,
    'Intel Pentium Quad Core N4200 1.1GHz': 28,
    'Intel Celeron Dual Core N3060 1.6GHz': 29,
    'Intel Core i5 1.3GHz': 30,
    'AMD FX 9830P 3GHz': 31,
    'Intel Core i7 7560U 2.4GHz': 32,
    'AMD E-Series 6110 1.5GHz': 33,
    'Intel Core i5 6200U 2.3GHz': 34,
    'Intel Core M 6Y75 1.2GHz': 35,
    'Intel Core i5 7500U 2.7GHz': 36,
    'Intel Core i3 6006U 2.2GHz': 37,
    'AMD A6-Series 9220 2.9GHz': 38,
    'Intel Core i7 6920HQ 2.9GHz': 39,
    'Intel Core i5 7Y54 1.2GHz': 40,
    'Intel Core i7 7820HK 2.9GHz': 41,
    'Intel Xeon E3-1505M V6 3GHz': 42,
    'AMD A6-Series 7310 2GHz': 43,
    'AMD A10-Series A10-9620P 2.5GHz': 44,
    'Intel Core i5 1.5GHz': 45,
    'Intel Core M 1.1GHz': 46,
    'Intel Core i5 6200U 2.5GHz': 47,
    'Intel Celeron Quad Core N3160 1.6GHz': 48,
    'AMD E-Series 9000e 1.5GHz': 49,
    'Intel Core i5 2.4GHz': 50,
}

# %%
df["Cpu"]=df["Cpu"].map(CPU_dict)

# %%
df.sample(20)
# Out:
#       Inches  ScreenResolution   Cpu   Ram                Memory   Gpu  \
# 1104    15.6               NaN   NaN  16.0          1.0TB Hybrid  45.0
# 1019    11.6               NaN  29.0   4.0    16GB Flash Storage   2.0
# 343     15.6               NaN   8.0   8.0  128GB SSD +  2TB HDD  25.0
# 1078    15.6               5.0   NaN  16.0  128GB SSD +  1TB HDD  86.0
# 432     15.6               5.0  25.0   8.0  128GB SSD +  1TB HDD  89.0
# 1011    14.0               NaN   NaN   2.0    32GB Flash Storage   2.0
# 787     13.3               NaN   3.0   8.0             256GB SSD  13.0
# 502     15.6              23.0   9.0   4.0               1TB HDD  19.0
# 191     17.3               5.0  25.0  16.0  256GB SSD +  1TB HDD  89.0
# 662     15.6               NaN  23.0   4.0             128GB SSD   4.0
# 966     13.3               9.0  13.0   8.0             256GB SSD  13.0
# 63      15.6               NaN  10.0   4.0             500GB HDD  24.0
# ...

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
MEM_dict={
    '128GB SSD': 1,
    '128GB Flash Storage': 2,
    '256GB SSD': 3,
    '512GB SSD': 4,
    '500GB HDD': 5,
    '256GB Flash Storage': 6,
    '1TB HDD': 7,
    '128GB SSD +  1TB HDD': 8,
    '256GB SSD +  256GB SSD': 9,
    '64GB Flash Storage': 10,
    '32GB Flash Storage': 11,
    '256GB SSD +  1TB HDD': 12,
    '256GB SSD +  2TB HDD': 13,
    '32GB SSD': 14,
    '2TB HDD': 15,
    '64GB SSD': 16,
    '1.0TB Hybrid': 17,
    '512GB SSD +  1TB HDD': 18,
    '1TB SSD': 19,
    '256GB SSD +  500GB HDD': 20,
    '128GB SSD +  2TB HDD': 21,
    '512GB SSD +  512GB SSD': 22,
    '16GB SSD': 23,
    '16GB Flash Storage': 24,
    '512GB SSD +  256GB SSD': 25,
    '512GB SSD +  2TB HDD': 26,
    '64GB Flash Storage +  1TB HDD': 27,
    '180GB SSD': 28,
    '1TB HDD +  1TB HDD': 29,
    '32GB HDD': 30,
    '1TB SSD +  1TB HDD': 31,
    '512GB Flash Storage': 32,
    '128GB HDD': 33,
    '240GB SSD': 34,
    '8GB SSD': 35,
    '508GB Hybrid': 36,
    '1.0TB HDD': 37,
    '512GB SSD +  1.0TB Hybrid': 38,
    '256GB SSD +  1.0TB Hybrid': 39,
}

# %%
df["Memory"]=df["Memory"].map(MEM_dict)

# %%
df.sample(20)
# Out:
#       Inches  ScreenResolution   Cpu   Ram  Memory   Gpu  Weight        Price  \
# 727     17.3               5.0   NaN  16.0       3  98.0    3.00  233845.9200
# 528     13.3              11.0  13.0   8.0       3  13.0    1.34   61005.6000
# 909     15.6               NaN   NaN   4.0       7   8.0    2.18   29762.2080
# 150     14.0               9.0  15.0   4.0       3  13.0    1.74   33513.1200
# 348     15.6               NaN  10.0   4.0       5   8.0    1.86   23389.9200
# 712     15.6               NaN   3.0   4.0       5  13.0    2.40   29783.5200
# 993     14.0               NaN  13.0   8.0       3  58.0    1.64   63159.7104
# 177     15.6               NaN   3.0   8.0       1  13.0    2.00   42251.0400
# 1024    13.3               NaN  13.0  16.0      19  13.0    1.20  120093.1200
# 1137    14.0               NaN  29.0   2.0      11   2.0    1.44   13266.7200
# 369     15.6               NaN  10.0   4.0       1   8.0    1.85   21498.4800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Inches            1241 non-null   float64
#  1   ScreenResolution  434 non-null    float64
#  2   Cpu               935 non-null    float64
#  3   Ram               1241 non-null   float64
#  4   Memory            1241 non-null   int64
#  5   Gpu               1169 non-null   float64
#  6   Weight            1241 non-null   float64
#  7   Price             1241 non-null   float64
#  8   Company_0         1241 non-null   int64
#  9   Company_1         1241 non-null   int64
#  10  Company_2         1241 non-null   int64
#  11  Company_3         1241 non-null   int64
#  12  Company_4         1241 non-null   int64
#  13  TypeName_0        1241 non-null   int64
#  14  TypeName_1        1241 non-null   int64
#  15  TypeName_2        1241 non-null   int64
# ...

# %% [markdown]
# #### now since all columns are INT or FLOAT and well encoded except screen resolution and CPU for reasons beyond potentials they are now ready for ML
